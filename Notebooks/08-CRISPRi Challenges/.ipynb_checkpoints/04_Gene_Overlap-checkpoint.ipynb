# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import json
import gpplot as gpp
from zipfile import ZipFile
gpp.set_aesthetics(context = 'paper')

# %%
def is_distance_less_than_x(row1, row2, start , end, x ):
    row2_range = range(int(row2[start]), int(row2[end]))
    #print(row1['Strand'])

    if row1['Strand'] == 1:
        start_row1_minus_end_row2 = abs(float(row1[start]) - float(row2[end]))
        start_row1_minus_start_row2 = abs(float(row1[start]) - float(row2[start]))
        start_row1_between_row2 = int(row1[start]) in row2_range
        return start_row1_minus_end_row2 < x or start_row1_minus_start_row2 < x or start_row1_between_row2
   
    elif row1['Strand'] == -1:
        end_row1_minus_start_row2 = abs(float(row1[end]) - float(row2[start]))
        end_row1_minus_end_row2 = abs(float(row1[end]) - float(row2[end]))
        end_row1_between_row2 = int(row1[end]) in row2_range
        return end_row1_minus_start_row2 < x or end_row1_minus_end_row2 < x or end_row1_between_row2
    else:
        raise Exception("The strand is neither 1 nor -1. Review is_distance_less_than_x!")

def add_element(dict, key, value):
    #https://stackoverflow.com/questions/33272588/appending-elements-to-an-empty-dictionary-of-lists-in-python
    if key not in dict:
        dict[key] = []
    if value not in dict[key]:  # Check if the value is not already in the list
        dict[key].append(value)

        
        
def overlap_list(biomart_df, start = 'Gene start (bp)', end = 'Gene end (bp)', x = 1000):
    filtered_objects = dict()

    for chromo in biomart_df['Chromosome/scaffold name'].unique():
        print(chromo)

    # select choromosom
        c1 = biomart_df[biomart_df['Chromosome/scaffold name'] == chromo]
#         # esstential gene in the chromosome
#         ess_gene_c1 = c1[c1['Gene name'].isin(ess_gene_list)]
        # Filter the DataFrame

        for i, row1 in c1.iterrows():
            for j, row2 in c1.iterrows():
                if i != j:
                    if is_distance_less_than_x(row1, row2, start = start, end = end, x = x):
                        add_element(filtered_objects, row1['Gene stable ID'], row2['Gene stable ID'])
                    else:
                        pass
    return filtered_objects
    
# Convert the dictionary into a list of tuples 
# then into df then melt datframe
def dict_to_df(example_dict):
    test_gene_overlap = []
    for key, value_list in example_dict.items():
        for value in value_list:
            test_gene_overlap.append((key, value))
    
    example_dict_data = pd.DataFrame(test_gene_overlap, columns=['Selected Gene', 'Overlapping Gene'])
    example_dict_data = example_dict_data.drop_duplicates()
    return example_dict_data

                    
def overlap_type(gene_1, gene_2, start = 'Gene start (bp)', end = 'Gene end (bp)', x = 1000):   

    # gene_1 and gene_2 are rows 
    if (float(gene_1['Strand'].iloc[0]) == 1) and (float(gene_2['Strand'].iloc[0]) == -1):
        distance_tss = abs(float(gene_1[start].iloc[0]) - float(gene_2[end].iloc[0]))
        other_distance_tss = abs(float(gene_1[start].iloc[0]) - float(gene_2[start].iloc[0]))

        if distance_tss <= x:
            return 2
        else:
            if other_distance_tss <= x:
                return 4
            else:
                return 5

    if (float(gene_1['Strand'].iloc[0]) == 1) and (float(gene_2['Strand'].iloc[0]) == 1):
        distance_tss = abs(float(gene_1[start].iloc[0]) - float(gene_2[start].iloc[0]))
        other_distance_tss_case1 = abs(float(gene_1[start].iloc[0]) - float(gene_2[end].iloc[0]))
        other_distance_tss_case2 = abs(float(gene_2[start].iloc[0]) - float(gene_1[end].iloc[0]))


        if distance_tss <= x:
            return 3
        else:

            if (other_distance_tss_case1 <= x) or (other_distance_tss_case2 <= x):
                return 1
            else:
                return 6
    
    if (float(gene_1['Strand'].iloc[0]) == -1) and (float(gene_2['Strand'].iloc[0]) == 1):
        distance_tss =  abs(float(gene_2[start].iloc[0]) - float(gene_1[end].iloc[0]))
        other_distance_tss = abs(float(gene_2[start].iloc[0]) - float(gene_1[start].iloc[0]))

        if distance_tss <= x:
            return 2
        else:
            if other_distance_tss <= x:
                return 4
            else:
                return 5
    if (float(gene_1['Strand'].iloc[0]) == -1) and (float(gene_2['Strand'].iloc[0]) == -1):
        distance_tss = abs(float(gene_1[end].iloc[0]) - float(gene_2[end].iloc[0]))
        other_distance_tss_case1 = abs(float(gene_1[end].iloc[0]) - float(gene_2[start].iloc[0]))
        other_distance_tss_case2 = abs(float(gene_2[end].iloc[0]) - float(gene_1[start].iloc[0]))

        if distance_tss <= x:
            return 3
        else:

            if (other_distance_tss_case1 <= x) or (other_distance_tss_case2 <= x):
                return 1
            else:
                return 6

# %%
#import biomart export
file_path = '../../Data/geneOverlap/'
biomart = pd.read_table(file_path + 'mart_export_genome_wide_01032024.txt', sep = ',', low_memory=False)
biomart
# Out:
#          Gene stable ID Gene stable ID version Transcript stable ID  \
# 0       ENSG00000210049      ENSG00000210049.1      ENST00000387314
# 1       ENSG00000211459      ENSG00000211459.2      ENST00000389680
# 2       ENSG00000210077      ENSG00000210077.1      ENST00000387342
# 3       ENSG00000210082      ENSG00000210082.2      ENST00000387347
# 4       ENSG00000209082      ENSG00000209082.1      ENST00000386347
# ...                 ...                    ...                  ...
# 276900  ENSG00000116786     ENSG00000116786.13      ENST00000375799
# 276901  ENSG00000116786     ENSG00000116786.13      ENST00000375793
# 276902  ENSG00000116786     ENSG00000116786.13      ENST00000462455
# 276903  ENSG00000116786     ENSG00000116786.13      ENST00000642363
# 276904  ENSG00000116786     ENSG00000116786.13      ENST00000477849
#
#        Transcript stable ID version       Gene type Gene name  \
# 0                 ENST00000387314.1         Mt_tRNA     MT-TF
# 1                 ENST00000389680.2         Mt_rRNA   MT-RNR1
# 2                 ENST00000387342.1         Mt_tRNA     MT-TV
# 3                 ENST00000387347.2         Mt_rRNA   MT-RNR2
# 4                 ENST00000386347.1         Mt_tRNA    MT-TL1
# ...                             ...             ...       ...
# 276900            ENST00000375799.8  protein_coding   PLEKHM2
# 276901            ENST00000375793.2  protein_coding   PLEKHM2
# 276902            ENST00000462455.1  protein_coding   PLEKHM2
# 276903            ENST00000642363.1  protein_coding   PLEKHM2
# 276904            ENST00000477849.1  protein_coding   PLEKHM2
#
#                                          Gene description  \
# 0       mitochondrially encoded tRNA-Phe (UUU/C) [Sour...
# 1       mitochondrially encoded 12S rRNA [Source:HGNC ...
# 2       mitochondrially encoded tRNA-Val (GUN) [Source...
# 3       mitochondrially encoded 16S rRNA [Source:HGNC ...
# 4       mitochondrially encoded tRNA-Leu (UUA/G) 1 [So...
# ...                                                   ...
# 276900  pleckstrin homology and RUN domain containing ...
# 276901  pleckstrin homology and RUN domain containing ...
# 276902  pleckstrin homology and RUN domain containing ...
# 276903  pleckstrin homology and RUN domain containing ...
# 276904  pleckstrin homology and RUN domain containing ...
#
#        Chromosome/scaffold name  Gene start (bp)  Gene end (bp)  \
# 0                            MT              577            647
# 1                            MT              648           1601
# 2                            MT             1602           1670
# 3                            MT             1671           3229
# 4                            MT             3230           3304
# ...                         ...              ...            ...
# 276900                        1         15684320       15734769
# 276901                        1         15684320       15734769
# 276902                        1         15684320       15734769
# 276903                        1         15684320       15734769
# 276904                        1         15684320       15734769
#
#         Transcription start site (TSS)  Strand  Transcript start (bp)  \
# 0                                  577       1                    577
# 1                                  648       1                    648
# 2                                 1602       1                   1602
# 3                                 1671       1                   1671
# 4                                 3230       1                   3230
# ...                                ...     ...                    ...
# 276900                        15684320       1               15684320
# 276901                        15684390       1               15684390
# 276902                        15684541       1               15684541
# 276903                        15684556       1               15684556
# 276904                        15729845       1               15729845
#
#         Transcript end (bp)
# 0                       647
# 1                      1601
# 2                      1670
# 3                      3229
# 4                      3304
# ...                     ...
# 276900             15734769
# 276901             15734769
# 276902             15719869
# 276903             15734769
# 276904             15734115
#
# [276905 rows x 14 columns]

# %%
#limit to chromosomes (remove unlocalized contigs/scaffolds)
chromo1_22 = [str(num) for num in range(1, 23)]
biomart = biomart[biomart['Chromosome/scaffold name'].isin(chromo1_22+['X','Y'])].copy()
#subset to protein coding genes
biomart_protein_coding = biomart[biomart['Gene type'] == 'protein_coding'].copy()
#drop duplicates
proteinCodingGeneNoDup = biomart_protein_coding.drop_duplicates('Gene stable ID')
proteinCodingGeneNoDup
# Out:
#          Gene stable ID Gene stable ID version Transcript stable ID  \
# 239     ENSG00000169789     ENSG00000169789.10      ENST00000303728
# 262     ENSG00000114374     ENSG00000114374.13      ENST00000457658
# 295     ENSG00000169807     ENSG00000169807.10      ENST00000303804
# 313     ENSG00000198692     ENSG00000198692.10      ENST00000361365
# 319     ENSG00000183753     ENSG00000183753.10      ENST00000602732
# ...                 ...                    ...                  ...
# 276873  ENSG00000116138     ENSG00000116138.13      ENST00000375838
# 276885  ENSG00000116771      ENSG00000116771.6      ENST00000375826
# 276890  ENSG00000197312     ENSG00000197312.13      ENST00000711098
# 276898  ENSG00000215695      ENSG00000215695.2      ENST00000345034
# 276900  ENSG00000116786     ENSG00000116786.13      ENST00000375799
#
#        Transcript stable ID version       Gene type Gene name  \
# 239               ENST00000303728.5  protein_coding       PRY
# 262               ENST00000457658.6  protein_coding     USP9Y
# 295               ENST00000303804.5  protein_coding      PRY2
# 313               ENST00000361365.7  protein_coding    EIF1AY
# 319               ENST00000602732.5  protein_coding      BPY2
# ...                             ...             ...       ...
# 276873            ENST00000375838.5  protein_coding   DNAJC16
# 276885            ENST00000375826.4  protein_coding     AGMAT
# 276890            ENST00000711098.1  protein_coding      DDI2
# 276898            ENST00000345034.2  protein_coding    RSC1A1
# 276900            ENST00000375799.8  protein_coding   PLEKHM2
#
#                                          Gene description  \
# 239     PTPN13 like Y-linked [Source:HGNC Symbol;Acc:H...
# 262     ubiquitin specific peptidase 9 Y-linked [Sourc...
# 295     PTPN13 like Y-linked 2 [Source:HGNC Symbol;Acc...
# 313     eukaryotic translation initiation factor 1A Y-...
# 319     basic charge Y-linked 2 [Source:HGNC Symbol;Ac...
# ...                                                   ...
# 276873  DnaJ heat shock protein family (Hsp40) member ...
# 276885     agmatinase [Source:HGNC Symbol;Acc:HGNC:18407]
# 276890  DNA damage inducible 1 homolog 2 [Source:HGNC ...
# 276898  regulator of solute carriers 1 [Source:HGNC Sy...
# 276900  pleckstrin homology and RUN domain containing ...
#
#        Chromosome/scaffold name  Gene start (bp)  Gene end (bp)  \
# 239                           Y         22490397       22514637
# 262                           Y         12537650       12860839
# 295                           Y         22071756       22096007
# 313                           Y         20575776       20593154
# 319                           Y         22973819       23005465
# ...                         ...              ...            ...
# 276873                        1         15526813       15592379
# 276885                        1         15571699       15585051
# 276890                        1         15617458       15669044
# 276898                        1         15659713       15662033
# 276900                        1         15684320       15734769
#
#         Transcription start site (TSS)  Strand  Transcript start (bp)  \
# 239                           22490397       1               22490397
# 262                           12537650       1               12537650
# 295                           22096007      -1               22071756
# 313                           20575776       1               20575776
# 319                           22973819       1               22973819
# ...                                ...     ...                    ...
# 276873                        15526813       1               15526813
# 276885                        15585051      -1               15571699
# 276890                        15617458       1               15617458
# 276898                        15659713       1               15659713
# 276900                        15684320       1               15684320
#
#         Transcript end (bp)
# 239                22514637
# 262                12708869
# 295                22096007
# 313                20593154
# 319                22992376
# ...                     ...
# 276873             15566595
# 276885             15585051
# 276890             15669044
# 276898             15662033
# 276900             15734769
#
# [20033 rows x 14 columns]

# %%
#create list of overlapping genes

# ensembl_protein_coding_gene_list = overlap_list(proteinCodingGeneNoDup, 
#                                                 start = 'Gene start (bp)', 
#                                                 end = 'Gene end (bp)', 
#                                                 x = 1000)

# # with open('../../Data/geneOverlap/all_tss_overlap_list.json', 'w') as file:
# #     json.dump(ensembl_protein_coding_gene_list, file)

# %%
#subset to just MANE Select TSSs
zip_file = ZipFile('../../Data/GENCODE48/gencode_48_protein_coding_transcripts.csv.zip')
gencode48 = pd.read_csv(zip_file.open('gencode_48_protein_coding_transcripts.csv'))
mane_transcripts = gencode48[gencode48['tag'].str.contains('MANE_Select') == True]['transcript_id_without_version'].tolist()
biomart_mane = biomart[biomart['Transcript stable ID'].isin(mane_transcripts)].copy()
biomart_mane
# Out:
#          Gene stable ID Gene stable ID version Transcript stable ID  \
# 266     ENSG00000114374     ENSG00000114374.13      ENST00000338981
# 313     ENSG00000198692     ENSG00000198692.10      ENST00000361365
# 320     ENSG00000183753     ENSG00000183753.10      ENST00000331070
# 405     ENSG00000236424      ENSG00000236424.7      ENST00000428845
# 430     ENSG00000258992      ENSG00000258992.7      ENST00000451548
# ...                 ...                    ...                  ...
# 276877  ENSG00000116138     ENSG00000116138.13      ENST00000375847
# 276885  ENSG00000116771      ENSG00000116771.6      ENST00000375826
# 276892  ENSG00000197312     ENSG00000197312.13      ENST00000480945
# 276898  ENSG00000215695      ENSG00000215695.2      ENST00000345034
# 276900  ENSG00000116786     ENSG00000116786.13      ENST00000375799
#
#        Transcript stable ID version       Gene type Gene name  \
# 266               ENST00000338981.7  protein_coding     USP9Y
# 313               ENST00000361365.7  protein_coding    EIF1AY
# 320               ENST00000331070.8  protein_coding      BPY2
# 405               ENST00000428845.6  protein_coding    TSPY10
# 430               ENST00000451548.6  protein_coding     TSPY1
# ...                             ...             ...       ...
# 276877            ENST00000375847.8  protein_coding   DNAJC16
# 276885            ENST00000375826.4  protein_coding     AGMAT
# 276892            ENST00000480945.6  protein_coding      DDI2
# 276898            ENST00000345034.2  protein_coding    RSC1A1
# 276900            ENST00000375799.8  protein_coding   PLEKHM2
#
#                                          Gene description  \
# 266     ubiquitin specific peptidase 9 Y-linked [Sourc...
# 313     eukaryotic translation initiation factor 1A Y-...
# 320     basic charge Y-linked 2 [Source:HGNC Symbol;Ac...
# 405     testis specific protein Y-linked 10 [Source:HG...
# 430     testis specific protein Y-linked 1 [Source:HGN...
# ...                                                   ...
# 276877  DnaJ heat shock protein family (Hsp40) member ...
# 276885     agmatinase [Source:HGNC Symbol;Acc:HGNC:18407]
# 276892  DNA damage inducible 1 homolog 2 [Source:HGNC ...
# 276898  regulator of solute carriers 1 [Source:HGNC Sy...
# 276900  pleckstrin homology and RUN domain containing ...
#
#        Chromosome/scaffold name  Gene start (bp)  Gene end (bp)  \
# 266                           Y         12537650       12860839
# 313                           Y         20575776       20593154
# 320                           Y         22973819       23005465
# 405                           Y          9527880        9530682
# 430                           Y          9466955        9469749
# ...                         ...              ...            ...
# 276877                        1         15526813       15592379
# 276885                        1         15571699       15585051
# 276892                        1         15617458       15669044
# 276898                        1         15659713       15662033
# 276900                        1         15684320       15734769
#
#         Transcription start site (TSS)  Strand  Transcript start (bp)  \
# 266                           12701231       1               12701231
# 313                           20575776       1               20575776
# 320                           22984263       1               22984263
# 405                            9527880       1                9527880
# 430                            9466955       1                9466955
# ...                                ...     ...                    ...
# 276877                        15526848       1               15526848
# 276885                        15585051      -1               15571699
# 276892                        15617458       1               15617458
# 276898                        15659713       1               15659713
# 276900                        15684320       1               15684320
#
#         Transcript end (bp)
# 266                12860839
# 313                20593154
# 320                23005465
# 405                 9530676
# 430                 9469749
# ...                     ...
# 276877             15571733
# 276885             15585051
# 276892             15669044
# 276898             15662033
# 276900             15734769
#
# [19209 rows x 14 columns]

# %%
# mane_tss_overlap_list = overlap_list(biomart_mane, 
#                                      start = 'Transcript start (bp)', 
#                                      end = 'Transcript end (bp)', 
#                                      x = 1000)

# with open('../../Data/geneOverlap/mane_tss_overlap_list.json', 'w') as file:
#     json.dump(mane_tss_overlap_list, file)

# %% [markdown]
# ### Scale of overlap when considering every Ensembl TSS per gene

# %%
with open('../../Data/geneOverlap/all_tss_overlap_list.json', 'r') as file:
    GW_ensembl_protein_coding = json.load(file)
GW_ensembl_protein_coding_df = dict_to_df(GW_ensembl_protein_coding)
GW_ensembl_protein_coding_df
# Out:
#         Selected Gene Overlapping Gene
# 0     ENSG00000099721  ENSG00000092377
# 1     ENSG00000092377  ENSG00000099721
# 2     ENSG00000292345  ENSG00000292338
# 3     ENSG00000132952  ENSG00000189403
# 4     ENSG00000189403  ENSG00000132952
# ...               ...              ...
# 7721  ENSG00000215704  ENSG00000142615
# 7722  ENSG00000132906  ENSG00000116138
# 7723  ENSG00000116138  ENSG00000132906
# 7724  ENSG00000116771  ENSG00000116138
# 7725  ENSG00000215695  ENSG00000197312
#
# [7726 rows x 2 columns]

# %%
total_gene = list(GW_ensembl_protein_coding_df['Selected Gene']) + list(GW_ensembl_protein_coding_df['Overlapping Gene'])

print(f'There are {len(set(total_gene))} genes with at least one overlap.')
print(f'This {100*(len(set(total_gene))/20033)} percent of total genes.')
# Out:
# There are 7218 genes with at least one overlap.
# This 36.030549593171266 percent of total genes.

# %%
# merge Overlapping gene
GW_ensembl_protein_coding_df = pd.merge(GW_ensembl_protein_coding_df,
         proteinCodingGeneNoDup[['Gene stable ID', 'Strand', 'Gene name','Gene start (bp)', 
                                'Gene end (bp)']].rename(columns = {'Gene stable ID': 'Overlapping Gene',
                                                            'Strand': 'Overlapping Strand', 
                                                              'Gene name': 'Overlapping Gene name',
                                                              'Gene start (bp)': 'Overlapping Gene start (bp)', 
                                                              'Gene end (bp)': 'Overlapping Gene end (bp)' }))

# %%
# merge Selected gene
GW_ensembl_protein_coding_df = pd.merge(GW_ensembl_protein_coding_df,
         proteinCodingGeneNoDup[['Gene stable ID', 'Strand', 'Gene name','Gene start (bp)', 
                                'Gene end (bp)']].rename(columns = {'Gene stable ID': 'Selected Gene',
                                                            'Strand': 'Selected Strand', 
                                                              'Gene name': 'Selected Gene name',
                                                              'Gene start (bp)': 'Selected Gene start (bp)', 
                                                              'Gene end (bp)': 'Selected Gene end (bp)' }))

# %%
for index, row in GW_ensembl_protein_coding_df.iterrows():
    gene_name_1 = row['Selected Gene']
    gene_name_2 = row['Overlapping Gene']
    gene_name_1_row = proteinCodingGeneNoDup[proteinCodingGeneNoDup['Gene stable ID'].isin([gene_name_1])]
    gene_name_2_row = proteinCodingGeneNoDup[proteinCodingGeneNoDup['Gene stable ID'].isin([gene_name_2])]
    overlap_type_number = overlap_type(gene_name_1_row, gene_name_2_row)
    GW_ensembl_protein_coding_df.loc[index,'overlap type'] = overlap_type_number

# %%
GW_ensembl_protein_coding_df.head()
# Out:
#      Selected Gene Overlapping Gene  Overlapping Strand Overlapping Gene name  \
# 0  ENSG00000099721  ENSG00000092377                   1                 TBL1Y
# 1  ENSG00000092377  ENSG00000099721                  -1                 AMELY
# 2  ENSG00000292345  ENSG00000292338                  -1                 DHRSX
# 3  ENSG00000132952  ENSG00000189403                  -1                 HMGB1
# 4  ENSG00000189403  ENSG00000132952                   1                 USPL1
#
#    Overlapping Gene start (bp)  Overlapping Gene end (bp)  Selected Strand  \
# 0                      6910686                    7101970               -1
# 1                      6865918                    6911752                1
# 2                      2219506                    2502805               -1
# 3                     30456704                   30617597                1
# 4                     30617693                   30660770               -1
#
#   Selected Gene name  Selected Gene start (bp)  Selected Gene end (bp)  \
# 0              AMELY                   6865918                 6911752
# 1              TBL1Y                   6910686                 7101970
# 2              ZBED1                   2486414                 2500976
# 3              USPL1                  30617693                30660770
# 4              HMGB1                  30456704                30617597
#
#    overlap type
# 0           5.0
# 1           5.0
# 2           6.0
# 3           2.0
# 4           2.0

# %%
#GW_ensembl_protein_coding_df.to_csv('../../Data/geneOverlap/GW_ensembl_protein_coding_df_1kb.csv', index = False)

# %% [markdown]
# ### Scale of overlap between MANE Select TSSs

# %%
with open('../../Data/geneOverlap/mane_tss_overlap_list.json', 'r') as file:
    GW_mane_protein_coding = json.load(file)
GW_mane_protein_coding_df = dict_to_df(GW_mane_protein_coding)
GW_mane_protein_coding_df
# Out:
#         Selected Gene Overlapping Gene
# 0     ENSG00000099721  ENSG00000092377
# 1     ENSG00000092377  ENSG00000099721
# 2     ENSG00000102547  ENSG00000136169
# 3     ENSG00000204899  ENSG00000136122
# 4     ENSG00000120685  ENSG00000188811
# ...               ...              ...
# 3155  ENSG00000197982  ENSG00000196449
# 3156  ENSG00000132128  ENSG00000173660
# 3157  ENSG00000173660  ENSG00000132128
# 3158  ENSG00000132781  ENSG00000132773
# 3159  ENSG00000215695  ENSG00000197312
#
# [3160 rows x 2 columns]

# %%
total_gene = list(GW_mane_protein_coding_df['Selected Gene']) + list(GW_mane_protein_coding_df['Overlapping Gene'])

print(f'There are {len(set(total_gene))} genes with at least one overlap.')
print(f'This {100*(len(set(total_gene))/19209)} percent of total genes.')
# Out:
# There are 3315 genes with at least one overlap.
# This 17.25753553022021 percent of total genes.

# %%
# merge Overlapping gene
GW_mane_protein_coding_df = pd.merge(GW_mane_protein_coding_df,
         biomart_mane[['Gene stable ID', 'Strand', 'Gene name','Transcript start (bp)', 
                                'Transcript end (bp)','Transcription start site (TSS)']].rename(columns = {'Gene stable ID': 'Overlapping Gene',
                                                            'Strand': 'Overlapping Strand', 
                                                              'Gene name': 'Overlapping Gene name',
                                                              'Transcript start (bp)': 'Overlapping Transcript start (bp)', 
                                                              'Transcript end (bp)': 'Overlapping Transcript end (bp)',
                                                            'Transcription start site (TSS)':'Overlapping TSS'}))
GW_mane_protein_coding_df
# Out:
#         Selected Gene Overlapping Gene  Overlapping Strand  \
# 0     ENSG00000099721  ENSG00000092377                   1
# 1     ENSG00000092377  ENSG00000099721                  -1
# 2     ENSG00000102547  ENSG00000136169                   1
# 3     ENSG00000136147  ENSG00000136169                   1
# 4     ENSG00000204899  ENSG00000136122                   1
# ...               ...              ...                 ...
# 3155  ENSG00000197982  ENSG00000196449                  -1
# 3156  ENSG00000132128  ENSG00000173660                   1
# 3157  ENSG00000173660  ENSG00000132128                  -1
# 3158  ENSG00000132781  ENSG00000132773                   1
# 3159  ENSG00000215695  ENSG00000197312                   1
#
#      Overlapping Gene name  Overlapping Transcript start (bp)  \
# 0                    TBL1Y                            6910697
# 1                    AMELY                            6865918
# 2                   SETDB2                           49444274
# 3                   SETDB2                           49444274
# 4                     BORA                           72727923
# ...                    ...                                ...
# 3155                  YRDC                           37802945
# 3156                 UQCRH                           46303698
# 3157                LRRC41                           46277462
# 3158                  TOE1                           45340170
# 3159                  DDI2                           15617458
#
#       Overlapping Transcript end (bp)  Overlapping TSS
# 0                             7091683          6910697
# 1                             6911752          6911752
# 2                            49495003         49444274
# 3                            49495003         49444274
# 4                            72756196         72727923
# ...                               ...              ...
# 3155                         37808208         37808208
# 3156                         46316776         46303698
# 3157                         46303616         46303616
# 3158                         45343973         45340170
# 3159                         15669044         15617458
#
# [3160 rows x 7 columns]

# %%
# merge Selected gene
GW_mane_protein_coding_df = pd.merge(GW_mane_protein_coding_df,
         biomart_mane[['Gene stable ID', 'Strand', 'Gene name','Transcript start (bp)', 
                                'Transcript end (bp)','Transcription start site (TSS)']].rename(columns = {'Gene stable ID': 'Selected Gene',
                                                            'Strand': 'Selected Strand', 
                                                              'Gene name': 'Selected Gene name',
                                                              'Transcript start (bp)': 'Selected Transcript start (bp)', 
                                                              'Transcript end (bp)': 'Selected Transcript end (bp)',
                                                            'Transcription start site (TSS)':'Selected TSS'}))
GW_mane_protein_coding_df
# Out:
#         Selected Gene Overlapping Gene  Overlapping Strand  \
# 0     ENSG00000099721  ENSG00000092377                   1
# 1     ENSG00000092377  ENSG00000099721                  -1
# 2     ENSG00000102547  ENSG00000136169                   1
# 3     ENSG00000136147  ENSG00000136169                   1
# 4     ENSG00000204899  ENSG00000136122                   1
# ...               ...              ...                 ...
# 3155  ENSG00000197982  ENSG00000196449                  -1
# 3156  ENSG00000132128  ENSG00000173660                   1
# 3157  ENSG00000173660  ENSG00000132128                  -1
# 3158  ENSG00000132781  ENSG00000132773                   1
# 3159  ENSG00000215695  ENSG00000197312                   1
#
#      Overlapping Gene name  Overlapping Transcript start (bp)  \
# 0                    TBL1Y                            6910697
# 1                    AMELY                            6865918
# 2                   SETDB2                           49444274
# 3                   SETDB2                           49444274
# 4                     BORA                           72727923
# ...                    ...                                ...
# 3155                  YRDC                           37802945
# 3156                 UQCRH                           46303698
# 3157                LRRC41                           46277462
# 3158                  TOE1                           45340170
# 3159                  DDI2                           15617458
#
#       Overlapping Transcript end (bp)  Overlapping TSS  Selected Strand  \
# 0                             7091683          6910697               -1
# 1                             6911752          6911752                1
# 2                            49495003         49444274               -1
# 3                            49495003         49444274                1
# 4                            72756196         72727923               -1
# ...                               ...              ...              ...
# 3155                         37808208         37808208                1
# 3156                         46316776         46303698               -1
# 3157                         46303616         46303616                1
# 3158                         45343973         45340170               -1
# 3159                         15669044         15617458                1
#
#      Selected Gene name  Selected Transcript start (bp)  \
# 0                 AMELY                         6865918
# 1                 TBL1Y                         6910697
# 2                CAB39L                        49308650
# 3                 PHF11                        49495953
# 4                  MZT1                        72708367
# ...                 ...                             ...
# 3155           C1orf122                        37807790
# 3156             LRRC41                        46277462
# 3157              UQCRH                        46303698
# 3158              MUTYH                        45329242
# 3159             RSC1A1                        15659713
#
#       Selected Transcript end (bp)  Selected TSS
# 0                          6911752       6911752
# 1                          7091683       6910697
# 2                         49444064      49444064
# 3                         49528976      49495953
# 4                         72727629      72727629
# ...                            ...           ...
# 3155                      37809454      37807790
# 3156                      46303616      46303616
# 3157                      46316776      46303698
# 3158                      45339970      45339970
# 3159                      15662033      15659713
#
# [3160 rows x 12 columns]

# %%
for index, row in GW_mane_protein_coding_df.iterrows():
    gene_name_1 = row['Selected Gene']
    gene_name_2 = row['Overlapping Gene']
    gene_name_1_row = biomart_mane[biomart_mane['Gene stable ID'].isin([gene_name_1])]
    gene_name_2_row = biomart_mane[biomart_mane['Gene stable ID'].isin([gene_name_2])]
    overlap_type_number = overlap_type(gene_name_1_row, gene_name_2_row, start = 'Transcript start (bp)', end = 'Transcript end (bp)')
    GW_mane_protein_coding_df.loc[index,'overlap type'] = overlap_type_number

# %%
GW_mane_protein_coding_df['overlap type'].value_counts()
# Out:
# 2.0    1890
# 1.0     466
# 6.0     461
# 5.0     232
# 3.0      92
# 4.0      19
# Name: overlap type, dtype: int64

# %%
GW_mane_protein_coding_df.to_csv('../../Data/geneOverlap/GW_mane_protein_coding_df_1kb.csv', index = False)

# %%
type23_overlap = GW_mane_protein_coding_df[GW_mane_protein_coding_df['overlap type'].isin([2,3])]
type23_overlap = type23_overlap[['Selected Gene',
                                 'Selected Gene name',
                                 'Selected Strand',
                                 'Selected TSS',
                                 'Overlapping Gene',
                                 'Overlapping Gene name',
                                 'Overlapping Strand',
                                 'Overlapping TSS']].drop_duplicates()
(np.abs(type23_overlap['Selected TSS'] - type23_overlap['Overlapping TSS']) < 1000).value_counts()
# Out:
# True    1982
# dtype: int64

# %%
type23_overlap.to_csv('../../Data/geneOverlap/GW_mane_overlapping_promoters_1kb.csv', index = False)

# %% [markdown]
# ### Plot frequency of each type of overlap when either all TSSs or only MANE TSSs are considered

# %%
graph_outpath = '../../Figures/Figure 6/'

# %%
num23_overlaps = GW_ensembl_protein_coding_df[GW_ensembl_protein_coding_df['overlap type'].isin([2,3])]['Selected Gene'].nunique()
num23_overlaps/proteinCodingGeneNoDup['Gene stable ID'].nunique()
# Out:
# 0.17361353766285628

# %%
num23_overlaps = GW_mane_protein_coding_df[GW_mane_protein_coding_df['overlap type'].isin([2,3])]['Selected Gene'].nunique()
num23_overlaps/biomart_mane['Gene stable ID'].nunique()
# Out:
# 0.10203550419074392

# %%
GW_ensembl_protein_coding_df['gene1_sorted'] = GW_ensembl_protein_coding_df[['Selected Gene','Overlapping Gene']].min(axis=1)
GW_ensembl_protein_coding_df['gene2_sorted'] = GW_ensembl_protein_coding_df[['Selected Gene','Overlapping Gene']].max(axis=1)
GW_ensembl_protein_coding_df['gene_pair_sorted'] = GW_ensembl_protein_coding_df['gene1_sorted'] + '_'+ GW_ensembl_protein_coding_df['gene2_sorted']
GW_ensembl_overlapping_pairs = GW_ensembl_protein_coding_df[['gene_pair_sorted','overlap type']].drop_duplicates()
GW_ensembl_overlapping_pairs
# Out:
#                      gene_pair_sorted  overlap type
# 0     ENSG00000092377_ENSG00000099721           5.0
# 2     ENSG00000292338_ENSG00000292345           6.0
# 3     ENSG00000132952_ENSG00000189403           2.0
# 5     ENSG00000182957_ENSG00000273167           3.0
# 6     ENSG00000182957_ENSG00000240654           1.0
# ...                               ...           ...
# 7720  ENSG00000160818_ENSG00000163382           5.0
# 7721  ENSG00000142615_ENSG00000215704           6.0
# 7722  ENSG00000116138_ENSG00000132906           2.0
# 7723  ENSG00000116138_ENSG00000116771           5.0
# 7725  ENSG00000197312_ENSG00000215695           6.0
#
# [5400 rows x 2 columns]

# %%
GW_mane_protein_coding_df['gene1_sorted'] = GW_mane_protein_coding_df[['Selected Gene','Overlapping Gene']].min(axis=1)
GW_mane_protein_coding_df['gene2_sorted'] = GW_mane_protein_coding_df[['Selected Gene','Overlapping Gene']].max(axis=1)
GW_mane_protein_coding_df['gene_pair_sorted'] = GW_mane_protein_coding_df['gene1_sorted'] + '_'+ GW_mane_protein_coding_df['gene2_sorted']
GW_mane_overlapping_pairs = GW_mane_protein_coding_df[['gene_pair_sorted','overlap type']].drop_duplicates()
GW_mane_overlapping_pairs
# Out:
#                      gene_pair_sorted  overlap type
# 0     ENSG00000092377_ENSG00000099721           5.0
# 2     ENSG00000102547_ENSG00000136169           2.0
# 3     ENSG00000136147_ENSG00000136169           1.0
# 4     ENSG00000136122_ENSG00000204899           2.0
# 5     ENSG00000120685_ENSG00000188811           2.0
# ...                               ...           ...
# 3149  ENSG00000116521_ENSG00000160767           1.0
# 3152  ENSG00000184007_ENSG00000288678           6.0
# 3154  ENSG00000196449_ENSG00000197982           2.0
# 3156  ENSG00000132128_ENSG00000173660           2.0
# 3159  ENSG00000197312_ENSG00000215695           6.0
#
# [2146 rows x 2 columns]

# %%
all_tss_overlap_count = GW_ensembl_protein_coding_df.groupby("overlap type").size().reset_index().rename(columns = {0:'num_gene'})
all_tss_overlap_count['Transcript Set Considered'] = 'GENCODE Comprehensive'
mane_overlap_count = GW_mane_protein_coding_df.groupby("overlap type").size().reset_index().rename(columns = {0:'num_gene'})
mane_overlap_count['Transcript Set Considered'] = 'MANE Select'

plot_df = pd.concat([all_tss_overlap_count,mane_overlap_count]).reset_index(drop=True)
default_palette = sns.color_palette("Set2")
sns.barplot(data = plot_df, x = 'overlap type', y = 'num_gene', hue = 'Transcript Set Considered',
           palette = {'GENCODE Comprehensive':default_palette[3],'MANE Select':default_palette[5]})
plt.xlabel('Overlap Type')
plt.ylabel('Number of Genes')
sns.despine()

gpp.savefig('../../Figures/Figure 6/num_overlapping_gene_sets_gencode_comprehensive_vs_mane.pdf', dpi=300, bbox_inches='tight')

# %%
all_tss_overlap_count
# Out:
#    overlap type  num_gene Transcript Set Considered
# 0           1.0       765     GENCODE Comprehensive
# 1           2.0      2792     GENCODE Comprehensive
# 2           3.0      1038     GENCODE Comprehensive
# 3           4.0        74     GENCODE Comprehensive
# 4           5.0      1456     GENCODE Comprehensive
# 5           6.0      1601     GENCODE Comprehensive

# %%
mane_overlap_count
# Out:
#    overlap type  num_gene Transcript Set Considered
# 0           1.0       466               MANE Select
# 1           2.0      1890               MANE Select
# 2           3.0        92               MANE Select
# 3           4.0        19               MANE Select
# 4           5.0       232               MANE Select
# 5           6.0       461               MANE Select
